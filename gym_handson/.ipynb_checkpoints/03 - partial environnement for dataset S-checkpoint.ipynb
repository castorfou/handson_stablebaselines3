# %% [markdown]
# # Janus gym environment

# %%
import gym
from gym import spaces
import random
import stable_baselines3
from stable_baselines3.common.env_checker import check_env
from stable_baselines3 import DQN, DDPG
from math import sqrt
import numpy as np
import pandas as pd
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import preprocessing
from sklearn.datasets import make_regression

import math
import pickle

class Janus(gym.Env):
    metadata = {'render.modes': ['human']}
    template_filename = 'data/dataset-S_public/public/dataset_S-{}.csv'

    def __init__(self):
        super(Janus, self).__init__()
        #actions: move on the grid, by continuous value in -1,1
        #0,0 no move
        #based on 94 controlable parameters
        #"We recommend you to use a symmetric and normalized Box action space (range=[-1, 1]) ", we will multiply effect by 2
#         self.action_space = spaces.Box(low=-1.0, high=1.0, shape=(94, ))
        #we focus on the 1 most influencal action
        nbr_actions = 4
        self.action_space = spaces.Box(low=-1.0, high=1.0, shape=(nbr_actions, ))
    

        # all the observation_space
        self.observation_space = spaces.Box(low=-1.0, high=1.0, shape=(228, ))

        file1 = pd.read_csv(self.template_filename.format('file1'), index_col=0)
        file2 = pd.read_csv(self.template_filename.format('file2'), index_col=0)
        file3 = pd.read_csv(self.template_filename.format('file3'), index_col=0)
        vav = pd.read_csv(self.template_filename.format('VAV'), index_col=0)
        self.ti = pd.read_csv(self.template_filename.format('TI'), index_col=0)
        self.ts = pd.read_csv(self.template_filename.format('TS'), index_col=0)
        x_df = file1.copy()
        x_df = x_df.loc[:, (x_df != 0).any(axis=0)]  ## remove static columns
        x_df = x_df.fillna(x_df.mean())  ## replace nan with mean

        self.y_df = file2.copy()
        self.y_df.dropna(how='all', axis=1,
                    inplace=True)  ## drop full tempty columns
        self.y_df = self.y_df.fillna(self.y_df.mean())

        self.vav_df = vav.copy()
        # Dropping few columns
        for dataset in [self.y_df, self.vav_df, self.ti, self.ts]:
            dataset.drop(['target_1', 'target_2', 'target_3', 'target_4'],
                  axis=1,
                  inplace=True)  #to simplify with a 2-dimension target space

        print('features shape: {}, \ntargets shape: {}'.format(
            x_df.shape, self.y_df.shape))

        x_train, x_test, y_train, y_test = train_test_split(x_df,
                                                            self.y_df,
                                                            test_size=0.1,
                                                            random_state=14)
        print('\nLength of train is {}, test is {}'.format(
            len(x_train), len(x_test)))
        ## Random forest
        filename = 'data/models/janus_RF.pkl'  # janus_LinearReg, janus_RF

        # pickle.dump(ml_model, open(filename, 'wb'))

        # # load the model from disk
        self.ml_model = pickle.load(open(filename, 'rb'))
        print(f'R squared: {self.ml_model.score(x_test, y_test.values):0.04f}')

        self.full_x = file3.copy()[x_df.columns]
        self.full_x = self.full_x.fillna(x_df.mean())
        
        self.partial_x = x_train.copy()

        inferred_y = pd.DataFrame(self.ml_model.predict(self.full_x),
                                  columns=self.y_df.columns)

        # list of [min, max, step, range] for each var
        scale = 100
        decimals = 3
        
        self.list_important_actions = np.argsort(self.ml_model.feature_importances_[:94])[::-1][:nbr_actions]

        ## get limits for Rewards
        self.output_steps = [round((self.y_df[i].max() - self.y_df[i].min())/scale, decimals) \
                        for i in self.y_df.columns]
        print('Output steps: ', self.output_steps)

    def reset(self):
#         self.current_position = self.revert_to_obs_space(
#             self.full_x.sample().values.reshape(-1), self.full_x)
        random.seed(13)
        idx = random.randint(0,len(janus_env.partial_x)-1)
        idx = 47
        self.current_position = self.revert_to_obs_space(
            self.full_x.iloc[idx].values.reshape(-1), self.full_x)
        
        # to fix The observation returned by the `reset()` method does not match the given observation space
        # maybe won't happen on linux
        # on windows looks like float64 is the defautl for pandas -> numpy and gym expects float32 (contains tries to cast to dtype(float32))
        self.current_position = self.current_position.astype('float32')
        
        self.last_action = self.current_position[self.list_important_actions]
        self.last_effect = False
        self.global_reward = 0
        self.episode_length = 0
        #print(f'reset at position {self.current_position[:10]}...')
        return self.current_position

    def step(self, action):
#         self.current_position[0:len(action)] = action
        for index, act in enumerate(self.list_important_actions):
            self.current_position[act]=action[index]
        self.last_action = action
        self.episode_length += 1
        done = False
        
        reward = self.reward(
            self.convert_to_real_obs(self.current_position,
                                     self.full_x).values.reshape(1,-1))
        if (reward >= -0.1*self.y_df.shape[1]):
            done = True
        
#         print(f'target reached {done} reward {reward:0.03f} n° step {self.episode_length} action {self.last_action} done threeshold {-0.1*self.y_df.shape[1]:0.03f}')
        
        if done:
            reward += 100
        
        if self.episode_length>100:
            print('episode too long -> reset')
            done = True
            
#         if (max(abs(action))==1):
#             # if on border, we kill episode
#             print('border reached -> done -> reset')
#             reward -= 50
#             done = True
            

        self.global_reward += reward
#         print(f'  reward {reward:0.03f} global reward {self.global_reward:0.03f} done {done} action {action} step {self.episode_length}')
        return self.current_position, reward, done, {}

    def render(self):
        print(
            f'position {self.current_position[:10]}, action {self.last_action[:5]}, effect {self.last_effect}, done {done}, global_reward {self.global_reward:0.03f}'
        )

    def convert_to_real_obs(self, observation, observation_dataset):
        '''
        to convert an observation from observation space ([-1, 1],325) to  real world
        -1 matches with min() of each column
        1 matches with max() of each column
        
        observation: instance of observation_space
        observation_dataset: the full real dataset (obfuscated in that case)
        '''
        return (observation + np.ones(self.observation_space.shape)) / 2 * (
            observation_dataset.max() -
            observation_dataset.min()) + observation_dataset.min()

    def revert_to_obs_space(self, real_observation, observation_dataset):
        '''
        to revert an observation sample (from real world) to observation space
        min() of each column will match with -1
        max() of each column will match with +1
        
        real_observation: instance of real_world
        observation_dataset: the full real dataset (obfuscated in that case)
        '''
        return np.nan_to_num(
            2 * (real_observation - observation_dataset.min()) /
            (observation_dataset.max() - observation_dataset.min()) -
            np.ones(self.observation_space.shape)).reshape(-1)

    def reward(self, observation):
        ''' Discrete reward 
        observation if from real world not observation space
        '''

        new_y = self.ml_model.predict(observation).reshape(-1)
        return self.continuous_reward_clown_hat(new_y)

    def discrete_reward(self, new_y):
        ''' Discrete reward '''

        new_val = [
            sqrt((self.vav_df.iloc[:, i].values[0] - new_y[i])**2)
            for i in range(len(new_y))
        ]
        k = 10
        k1 = 1
        if new_val[0] < k * self.output_steps[0] and new_val[
                1] < k * self.output_steps[1]:
            reward = 1  #dans les 10% d'amplitude max autour de la vav
            if new_val[0] < k1 * self.output_steps[0] and new_val[
                    1] < k1 * self.output_steps[1]:
                reward = 10  #dans les 1% d'amplitude max autour de la vav
                on_target = True
#                 print('On Target : ', new_y)
        else:
            reward = -1
        return reward
    
    
    
    def continuous_reward_clown_hat(self, new_y):
        ''' Continuous reward '''
        final_reward = 0 

        for i in range(len(new_y)):
            reward = -9
            if ( self.ti.iloc[:,i].values[0] <=  new_y[i] <= self.ts.iloc[:,i].values[0]):
                if ( new_y[i] >= self.vav_df.iloc[:,i].values[0] ):
                    reward = 1-(new_y[i]-self.vav_df.iloc[:,i].values[0])/(self.ts.iloc[:,i].values[0]-self.vav_df.iloc[:,i].values[0])
                else:
                    reward = 1-(new_y[i]-self.ti.iloc[:,i].values[0])/(self.vav_df.iloc[:,i].values[0]-self.ti.iloc[:,i].values[0])
            reward += -1
            final_reward+=reward
    #         print(f'reward {reward} final_reward {final_reward} i {i}')

        if (final_reward>0.7*len(new_y)):
            on_target = True
    #         print('On Target : ', new_y)

        return final_reward

# %%
janus_env = Janus()
from stable_baselines3.common.env_checker import check_env

check_env(janus_env)
# Out:
# features shape: (782, 228),
# targets shape: (782, 2)
#
# Length of train is 703, test is 79
# R squared: 0.6615
# Output steps:  [0.064, 0.057]

# %% [markdown]
# # SAC training

# %%
from stable_baselines3 import SAC

janus_env = Janus()
check_env(janus_env)

model_janus_sac = SAC("MlpPolicy", janus_env, verbose=2,tensorboard_log="./tensorboard/")
model_janus_sac.learn(total_timesteps=100000, log_interval=4, tb_log_name="janus partial sac")

janus_env.reset()
for i in range(100):
    action, _ = model_janus_sac.predict(janus_env.current_position)
    print(f'action {action}')
    obs, rewards, done, info = janus_env.step(action)
    janus_env.render()
    if done: break
janus_env.close()
# Out:
# features shape: (782, 228),
# targets shape: (782, 2)
#
# Length of train is 703, test is 79
# R squared: 0.6550
# Output steps:  [0.064, 0.057]
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to ./tensorboard/janus partial sac_3
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 27       |
# |    time_elapsed    | 14       |
# |    total timesteps | 404      |
# | train/             |          |
# |    actor_loss      | 0.392    |
# |    critic_loss     | 0.0128   |
# |    ent_coef        | 0.913    |
# |    ent_coef_loss   | -0.153   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 303      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 26       |
# |    time_elapsed    | 30       |
# |    total timesteps | 808      |
# | train/             |          |
# |    actor_loss      | 1.3      |
# |    critic_loss     | 0.0106   |
# |    ent_coef        | 0.809    |
# |    ent_coef_loss   | -0.355   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 707      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 25       |
# |    time_elapsed    | 46       |
# |    total timesteps | 1212     |
# | train/             |          |
# |    actor_loss      | 2.22     |
# |    critic_loss     | 0.0326   |
# |    ent_coef        | 0.717    |
# |    ent_coef_loss   | -0.56    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1111     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 25       |
# |    time_elapsed    | 63       |
# |    total timesteps | 1616     |
# | train/             |          |
# |    actor_loss      | 3.28     |
# |    critic_loss     | 0.0936   |
# |    ent_coef        | 0.635    |
# |    ent_coef_loss   | -0.768   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1515     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 25       |
# |    time_elapsed    | 79       |
# |    total timesteps | 2020     |
# | train/             |          |
# |    actor_loss      | 4.48     |
# |    critic_loss     | 0.00764  |
# |    ent_coef        | 0.562    |
# |    ent_coef_loss   | -0.963   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1919     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 25       |
# |    time_elapsed    | 95       |
# |    total timesteps | 2424     |
# | train/             |          |
# |    actor_loss      | 5.59     |
# |    critic_loss     | 0.566    |
# |    ent_coef        | 0.498    |
# |    ent_coef_loss   | -1.18    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2323     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 25       |
# |    time_elapsed    | 112      |
# |    total timesteps | 2828     |
# | train/             |          |
# |    actor_loss      | 6.75     |
# |    critic_loss     | 0.293    |
# |    ent_coef        | 0.441    |
# |    ent_coef_loss   | -1.38    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2727     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 25       |
# |    time_elapsed    | 128      |
# |    total timesteps | 3232     |
# | train/             |          |
# |    actor_loss      | 8.06     |
# |    critic_loss     | 0.207    |
# |    ent_coef        | 0.391    |
# |    ent_coef_loss   | -1.58    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3131     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 25       |
# |    time_elapsed    | 144      |
# |    total timesteps | 3636     |
# | train/             |          |
# |    actor_loss      | 9.2      |
# |    critic_loss     | 0.557    |
# |    ent_coef        | 0.347    |
# |    ent_coef_loss   | -1.75    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3535     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 25       |
# |    time_elapsed    | 161      |
# |    total timesteps | 4040     |
# | train/             |          |
# |    actor_loss      | 10.4     |
# |    critic_loss     | 1.82     |
# |    ent_coef        | 0.307    |
# |    ent_coef_loss   | -1.98    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3939     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 24       |
# |    time_elapsed    | 178      |
# |    total timesteps | 4444     |
# | train/             |          |
# |    actor_loss      | 11.6     |
# |    critic_loss     | 2.29     |
# |    ent_coef        | 0.272    |
# |    ent_coef_loss   | -2.17    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4343     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 24       |
# |    time_elapsed    | 194      |
# |    total timesteps | 4848     |
# | train/             |          |
# |    actor_loss      | 12.7     |
# |    critic_loss     | 1.7      |
# |    ent_coef        | 0.241    |
# |    ent_coef_loss   | -2.39    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4747     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 24       |
# |    time_elapsed    | 211      |
# |    total timesteps | 5252     |
# | train/             |          |
# |    actor_loss      | 13.9     |
# |    critic_loss     | 4.15     |
# |    ent_coef        | 0.214    |
# |    ent_coef_loss   | -2.58    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5151     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 24       |
# |    time_elapsed    | 227      |
# |    total timesteps | 5656     |
# | train/             |          |
# |    actor_loss      | 15.4     |
# |    critic_loss     | 0.813    |
# |    ent_coef        | 0.189    |
# |    ent_coef_loss   | -2.78    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5555     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 24       |
# |    time_elapsed    | 244      |
# |    total timesteps | 6060     |
# | train/             |          |
# |    actor_loss      | 16.6     |
# |    critic_loss     | 0.957    |
# |    ent_coef        | 0.168    |
# |    ent_coef_loss   | -3.01    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5959     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 24       |
# |    time_elapsed    | 260      |
# |    total timesteps | 6464     |
# | train/             |          |
# |    actor_loss      | 17.7     |
# |    critic_loss     | 3.35     |
# |    ent_coef        | 0.148    |
# |    ent_coef_loss   | -3.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6363     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 24       |
# |    time_elapsed    | 276      |
# |    total timesteps | 6868     |
# | train/             |          |
# |    actor_loss      | 18.8     |
# |    critic_loss     | 0.0196   |
# |    ent_coef        | 0.132    |
# |    ent_coef_loss   | -3.32    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6767     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 24       |
# |    time_elapsed    | 292      |
# |    total timesteps | 7272     |
# | train/             |          |
# |    actor_loss      | 19.8     |
# |    critic_loss     | 2.84     |
# |    ent_coef        | 0.117    |
# |    ent_coef_loss   | -3.57    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7171     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 24       |
# |    time_elapsed    | 309      |
# |    total timesteps | 7676     |
# | train/             |          |
# |    actor_loss      | 20.7     |
# |    critic_loss     | 0.272    |
# |    ent_coef        | 0.103    |
# |    ent_coef_loss   | -3.82    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7575     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 24       |
# |    time_elapsed    | 326      |
# |    total timesteps | 8080     |
# | train/             |          |
# |    actor_loss      | 21.8     |
# |    critic_loss     | 5.16     |
# |    ent_coef        | 0.0916   |
# |    ent_coef_loss   | -3.96    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7979     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 24       |
# |    time_elapsed    | 344      |
# |    total timesteps | 8484     |
# | train/             |          |
# |    actor_loss      | 23.1     |
# |    critic_loss     | 3.78     |
# |    ent_coef        | 0.0812   |
# |    ent_coef_loss   | -4.07    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8383     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 24       |
# |    time_elapsed    | 362      |
# |    total timesteps | 8888     |
# | train/             |          |
# |    actor_loss      | 23.8     |
# |    critic_loss     | 4.2      |
# |    ent_coef        | 0.0721   |
# |    ent_coef_loss   | -4.26    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8787     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 24       |
# |    time_elapsed    | 383      |
# |    total timesteps | 9292     |
# | train/             |          |
# |    actor_loss      | 24.9     |
# |    critic_loss     | 9.03     |
# |    ent_coef        | 0.0642   |
# |    ent_coef_loss   | -4.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9191     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 24       |
# |    time_elapsed    | 402      |
# |    total timesteps | 9696     |
# | train/             |          |
# |    actor_loss      | 26       |
# |    critic_loss     | 0.0186   |
# |    ent_coef        | 0.0571   |
# |    ent_coef_loss   | -3.93    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9595     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 23       |
# |    time_elapsed    | 421      |
# |    total timesteps | 10100    |
# | train/             |          |
# |    actor_loss      | 26.6     |
# |    critic_loss     | 10.4     |
# |    ent_coef        | 0.051    |
# |    ent_coef_loss   | -4.44    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 23       |
# |    time_elapsed    | 440      |
# |    total timesteps | 10504    |
# | train/             |          |
# |    actor_loss      | 27.6     |
# |    critic_loss     | 2.79     |
# |    ent_coef        | 0.0457   |
# |    ent_coef_loss   | -4.43    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10403    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 23       |
# |    time_elapsed    | 459      |
# |    total timesteps | 10908    |
# | train/             |          |
# |    actor_loss      | 28.2     |
# |    critic_loss     | 3.08     |
# |    ent_coef        | 0.0407   |
# |    ent_coef_loss   | -4.22    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10807    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 23       |
# |    time_elapsed    | 478      |
# |    total timesteps | 11312    |
# | train/             |          |
# |    actor_loss      | 29       |
# |    critic_loss     | 9.44     |
# |    ent_coef        | 0.0362   |
# |    ent_coef_loss   | -3.74    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11211    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 23       |
# |    time_elapsed    | 497      |
# |    total timesteps | 11716    |
# | train/             |          |
# |    actor_loss      | 29.8     |
# |    critic_loss     | 3.51     |
# |    ent_coef        | 0.0326   |
# |    ent_coef_loss   | -3.68    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11615    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 23       |
# |    time_elapsed    | 517      |
# |    total timesteps | 12120    |
# | train/             |          |
# |    actor_loss      | 30.4     |
# |    critic_loss     | 17.2     |
# |    ent_coef        | 0.0301   |
# |    ent_coef_loss   | -2.55    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12019    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 23       |
# |    time_elapsed    | 536      |
# |    total timesteps | 12524    |
# | train/             |          |
# |    actor_loss      | 31       |
# |    critic_loss     | 3.8      |
# |    ent_coef        | 0.0278   |
# |    ent_coef_loss   | -1.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12423    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 23       |
# |    time_elapsed    | 555      |
# |    total timesteps | 12928    |
# | train/             |          |
# |    actor_loss      | 31.9     |
# |    critic_loss     | 15.1     |
# |    ent_coef        | 0.026    |
# |    ent_coef_loss   | -2.25    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12827    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 23       |
# |    time_elapsed    | 574      |
# |    total timesteps | 13332    |
# | train/             |          |
# |    actor_loss      | 32.7     |
# |    critic_loss     | 7.96     |
# |    ent_coef        | 0.0237   |
# |    ent_coef_loss   | -1.86    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13231    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 23       |
# |    time_elapsed    | 592      |
# |    total timesteps | 13736    |
# | train/             |          |
# |    actor_loss      | 33.2     |
# |    critic_loss     | 24.8     |
# |    ent_coef        | 0.0215   |
# |    ent_coef_loss   | -2.87    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13635    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 23       |
# |    time_elapsed    | 611      |
# |    total timesteps | 14140    |
# | train/             |          |
# |    actor_loss      | 34       |
# |    critic_loss     | 8.57     |
# |    ent_coef        | 0.0189   |
# |    ent_coef_loss   | -3.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14039    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 23       |
# |    time_elapsed    | 631      |
# |    total timesteps | 14544    |
# | train/             |          |
# |    actor_loss      | 34.4     |
# |    critic_loss     | 8.82     |
# |    ent_coef        | 0.0171   |
# |    ent_coef_loss   | -2.48    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14443    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 22       |
# |    time_elapsed    | 651      |
# |    total timesteps | 14948    |
# | train/             |          |
# |    actor_loss      | 34.8     |
# |    critic_loss     | 18.2     |
# |    ent_coef        | 0.0162   |
# |    ent_coef_loss   | -1.75    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14847    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 22       |
# |    time_elapsed    | 670      |
# |    total timesteps | 15352    |
# | train/             |          |
# |    actor_loss      | 35.2     |
# |    critic_loss     | 0.561    |
# |    ent_coef        | 0.0143   |
# |    ent_coef_loss   | -3.15    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15251    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 22       |
# |    time_elapsed    | 688      |
# |    total timesteps | 15756    |
# | train/             |          |
# |    actor_loss      | 36.2     |
# |    critic_loss     | 14.6     |
# |    ent_coef        | 0.0126   |
# |    ent_coef_loss   | -2.12    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15655    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 22       |
# |    time_elapsed    | 706      |
# |    total timesteps | 16160    |
# | train/             |          |
# |    actor_loss      | 36.2     |
# |    critic_loss     | 24.7     |
# |    ent_coef        | 0.0123   |
# |    ent_coef_loss   | -0.608   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16059    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 22       |
# |    time_elapsed    | 724      |
# |    total timesteps | 16564    |
# | train/             |          |
# |    actor_loss      | 37.1     |
# |    critic_loss     | 15.5     |
# |    ent_coef        | 0.0111   |
# |    ent_coef_loss   | -4       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16463    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 22       |
# |    time_elapsed    | 742      |
# |    total timesteps | 16968    |
# | train/             |          |
# |    actor_loss      | 37.9     |
# |    critic_loss     | 0.0136   |
# |    ent_coef        | 0.00987  |
# |    ent_coef_loss   | -2.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16867    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 22       |
# |    time_elapsed    | 760      |
# |    total timesteps | 17372    |
# | train/             |          |
# |    actor_loss      | 38.4     |
# |    critic_loss     | 5.45     |
# |    ent_coef        | 0.00943  |
# |    ent_coef_loss   | 0.359    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 17271    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 22       |
# |    time_elapsed    | 779      |
# |    total timesteps | 17776    |
# | train/             |          |
# |    actor_loss      | 38.8     |
# |    critic_loss     | 5.61     |
# |    ent_coef        | 0.00934  |
# |    ent_coef_loss   | 0.836    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 17675    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 22       |
# |    time_elapsed    | 799      |
# |    total timesteps | 18180    |
# | train/             |          |
# |    actor_loss      | 39.1     |
# |    critic_loss     | 46.2     |
# |    ent_coef        | 0.00898  |
# |    ent_coef_loss   | -0.818   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 18079    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 22       |
# |    time_elapsed    | 817      |
# |    total timesteps | 18584    |
# | train/             |          |
# |    actor_loss      | 39.4     |
# |    critic_loss     | 17.5     |
# |    ent_coef        | 0.00779  |
# |    ent_coef_loss   | -4.05    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 18483    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 22       |
# |    time_elapsed    | 837      |
# |    total timesteps | 18988    |
# | train/             |          |
# |    actor_loss      | 40.3     |
# |    critic_loss     | 0.0149   |
# |    ent_coef        | 0.00716  |
# |    ent_coef_loss   | 1.47     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 18887    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 22       |
# |    time_elapsed    | 855      |
# |    total timesteps | 19392    |
# | train/             |          |
# |    actor_loss      | 40.2     |
# |    critic_loss     | 6.24     |
# |    ent_coef        | 0.0079   |
# |    ent_coef_loss   | 1.65     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 19291    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 22       |
# |    time_elapsed    | 874      |
# |    total timesteps | 19796    |
# | train/             |          |
# |    actor_loss      | 39.9     |
# |    critic_loss     | 18.7     |
# |    ent_coef        | 0.00801  |
# |    ent_coef_loss   | 1.19     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 19695    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 22       |
# |    time_elapsed    | 893      |
# |    total timesteps | 20200    |
# | train/             |          |
# |    actor_loss      | 40.9     |
# |    critic_loss     | 12.6     |
# |    ent_coef        | 0.00763  |
# |    ent_coef_loss   | -5.53    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 20099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 22       |
# |    time_elapsed    | 913      |
# |    total timesteps | 20604    |
# | train/             |          |
# |    actor_loss      | 41.3     |
# |    critic_loss     | 19.1     |
# |    ent_coef        | 0.00673  |
# |    ent_coef_loss   | 0.536    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 20503    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 22       |
# |    time_elapsed    | 930      |
# |    total timesteps | 21008    |
# | train/             |          |
# |    actor_loss      | 41.3     |
# |    critic_loss     | 19.6     |
# |    ent_coef        | 0.00749  |
# |    ent_coef_loss   | 2.86     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 20907    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 22       |
# |    time_elapsed    | 946      |
# |    total timesteps | 21412    |
# | train/             |          |
# |    actor_loss      | 42.2     |
# |    critic_loss     | 13.3     |
# |    ent_coef        | 0.00749  |
# |    ent_coef_loss   | 0.794    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 21311    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 22       |
# |    time_elapsed    | 962      |
# |    total timesteps | 21816    |
# | train/             |          |
# |    actor_loss      | 41.9     |
# |    critic_loss     | 20       |
# |    ent_coef        | 0.00803  |
# |    ent_coef_loss   | 0.18     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 21715    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 22       |
# |    time_elapsed    | 979      |
# |    total timesteps | 22220    |
# | train/             |          |
# |    actor_loss      | 42.4     |
# |    critic_loss     | 13.6     |
# |    ent_coef        | 0.00809  |
# |    ent_coef_loss   | -2.35    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 22119    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 22       |
# |    time_elapsed    | 994      |
# |    total timesteps | 22624    |
# | train/             |          |
# |    actor_loss      | 43.4     |
# |    critic_loss     | 6.93     |
# |    ent_coef        | 0.00631  |
# |    ent_coef_loss   | -6.81    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 22523    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 22       |
# |    time_elapsed    | 1011     |
# |    total timesteps | 23028    |
# | train/             |          |
# |    actor_loss      | 42.7     |
# |    critic_loss     | 7.35     |
# |    ent_coef        | 0.00566  |
# |    ent_coef_loss   | 1.45     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 22927    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 22       |
# |    time_elapsed    | 1027     |
# |    total timesteps | 23432    |
# | train/             |          |
# |    actor_loss      | 43.2     |
# |    critic_loss     | 21       |
# |    ent_coef        | 0.00603  |
# |    ent_coef_loss   | 4.16     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23331    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 22       |
# |    time_elapsed    | 1043     |
# |    total timesteps | 23836    |
# | train/             |          |
# |    actor_loss      | 43.6     |
# |    critic_loss     | 0.0757   |
# |    ent_coef        | 0.00661  |
# |    ent_coef_loss   | 1.82     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23735    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 22       |
# |    time_elapsed    | 1059     |
# |    total timesteps | 24240    |
# | train/             |          |
# |    actor_loss      | 42.9     |
# |    critic_loss     | 29       |
# |    ent_coef        | 0.00689  |
# |    ent_coef_loss   | 1.22     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 24139    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 22       |
# |    time_elapsed    | 1076     |
# |    total timesteps | 24644    |
# | train/             |          |
# |    actor_loss      | 43.8     |
# |    critic_loss     | 28.9     |
# |    ent_coef        | 0.00685  |
# |    ent_coef_loss   | 1.73     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 24543    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 22       |
# |    time_elapsed    | 1092     |
# |    total timesteps | 25048    |
# | train/             |          |
# |    actor_loss      | 43.7     |
# |    critic_loss     | 36.3     |
# |    ent_coef        | 0.00783  |
# |    ent_coef_loss   | 2.77     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 24947    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 22       |
# |    time_elapsed    | 1109     |
# |    total timesteps | 25452    |
# | train/             |          |
# |    actor_loss      | 44.4     |
# |    critic_loss     | 44.5     |
# |    ent_coef        | 0.00868  |
# |    ent_coef_loss   | 1.25     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 25351    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 22       |
# |    time_elapsed    | 1125     |
# |    total timesteps | 25856    |
# | train/             |          |
# |    actor_loss      | 44.3     |
# |    critic_loss     | 8.02     |
# |    ent_coef        | 0.00927  |
# |    ent_coef_loss   | 0.0228   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 25755    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 23       |
# |    time_elapsed    | 1141     |
# |    total timesteps | 26260    |
# | train/             |          |
# |    actor_loss      | 44.5     |
# |    critic_loss     | 52.3     |
# |    ent_coef        | 0.00881  |
# |    ent_coef_loss   | -1.65    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 26159    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 23       |
# |    time_elapsed    | 1158     |
# |    total timesteps | 26664    |
# | train/             |          |
# |    actor_loss      | 44.7     |
# |    critic_loss     | 22.7     |
# |    ent_coef        | 0.00868  |
# |    ent_coef_loss   | -0.359   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 26563    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 23       |
# |    time_elapsed    | 1174     |
# |    total timesteps | 27068    |
# | train/             |          |
# |    actor_loss      | 44.7     |
# |    critic_loss     | 23       |
# |    ent_coef        | 0.00893  |
# |    ent_coef_loss   | 1.99     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 26967    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 23       |
# |    time_elapsed    | 1190     |
# |    total timesteps | 27472    |
# | train/             |          |
# |    actor_loss      | 45       |
# |    critic_loss     | 15.7     |
# |    ent_coef        | 0.00974  |
# |    ent_coef_loss   | 1.13     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 27371    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 23       |
# |    time_elapsed    | 1206     |
# |    total timesteps | 27876    |
# | train/             |          |
# |    actor_loss      | 46       |
# |    critic_loss     | 7.88     |
# |    ent_coef        | 0.0105   |
# |    ent_coef_loss   | -0.802   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 27775    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 23       |
# |    time_elapsed    | 1223     |
# |    total timesteps | 28280    |
# | train/             |          |
# |    actor_loss      | 45.3     |
# |    critic_loss     | 15.9     |
# |    ent_coef        | 0.00845  |
# |    ent_coef_loss   | -1.99    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 28179    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 23       |
# |    time_elapsed    | 1239     |
# |    total timesteps | 28684    |
# | train/             |          |
# |    actor_loss      | 46.3     |
# |    critic_loss     | 15.9     |
# |    ent_coef        | 0.00765  |
# |    ent_coef_loss   | 0.201    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 28583    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 23       |
# |    time_elapsed    | 1255     |
# |    total timesteps | 29088    |
# | train/             |          |
# |    actor_loss      | 46.1     |
# |    critic_loss     | 56.1     |
# |    ent_coef        | 0.0069   |
# |    ent_coef_loss   | -1.29    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 28987    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 23       |
# |    time_elapsed    | 1272     |
# |    total timesteps | 29492    |
# | train/             |          |
# |    actor_loss      | 46.4     |
# |    critic_loss     | 32.4     |
# |    ent_coef        | 0.00744  |
# |    ent_coef_loss   | 1.54     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 29391    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 23       |
# |    time_elapsed    | 1288     |
# |    total timesteps | 29896    |
# | train/             |          |
# |    actor_loss      | 46.7     |
# |    critic_loss     | 41.3     |
# |    ent_coef        | 0.00795  |
# |    ent_coef_loss   | -0.138   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 29795    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 23       |
# |    time_elapsed    | 1304     |
# |    total timesteps | 30300    |
# | train/             |          |
# |    actor_loss      | 46.5     |
# |    critic_loss     | 24.5     |
# |    ent_coef        | 0.00742  |
# |    ent_coef_loss   | -0.483   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 30199    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 23       |
# |    time_elapsed    | 1320     |
# |    total timesteps | 30704    |
# | train/             |          |
# |    actor_loss      | 46.5     |
# |    critic_loss     | 57       |
# |    ent_coef        | 0.00692  |
# |    ent_coef_loss   | 1.38     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 30603    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 23       |
# |    time_elapsed    | 1337     |
# |    total timesteps | 31108    |
# | train/             |          |
# |    actor_loss      | 47.2     |
# |    critic_loss     | 0.0103   |
# |    ent_coef        | 0.00702  |
# |    ent_coef_loss   | -1.98    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 31007    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 23       |
# |    time_elapsed    | 1353     |
# |    total timesteps | 31512    |
# | train/             |          |
# |    actor_loss      | 47.3     |
# |    critic_loss     | 8.38     |
# |    ent_coef        | 0.00637  |
# |    ent_coef_loss   | -0.574   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 31411    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 23       |
# |    time_elapsed    | 1369     |
# |    total timesteps | 31916    |
# | train/             |          |
# |    actor_loss      | 47.6     |
# |    critic_loss     | 0.00179  |
# |    ent_coef        | 0.00591  |
# |    ent_coef_loss   | -2.21    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 31815    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 23       |
# |    time_elapsed    | 1386     |
# |    total timesteps | 32320    |
# | train/             |          |
# |    actor_loss      | 47.1     |
# |    critic_loss     | 0.608    |
# |    ent_coef        | 0.00535  |
# |    ent_coef_loss   | 1.08     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 32219    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 23       |
# |    time_elapsed    | 1402     |
# |    total timesteps | 32724    |
# | train/             |          |
# |    actor_loss      | 47.2     |
# |    critic_loss     | 8.8      |
# |    ent_coef        | 0.00537  |
# |    ent_coef_loss   | 1.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 32623    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 23       |
# |    time_elapsed    | 1418     |
# |    total timesteps | 33128    |
# | train/             |          |
# |    actor_loss      | 47       |
# |    critic_loss     | 17.4     |
# |    ent_coef        | 0.0063   |
# |    ent_coef_loss   | 2.88     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 33027    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 23       |
# |    time_elapsed    | 1434     |
# |    total timesteps | 33532    |
# ...
# position [ 0.98472524 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.98472524], effect False, done False, global_reward -27
# action [0.29568815]
# position [ 0.29568815 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.29568815], effect False, done False, global_reward -28
# action [0.9501914]
# position [ 0.95019138 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.9501914], effect False, done False, global_reward -29
# action [0.7965498]
# position [ 0.7965498  -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.7965498], effect False, done False, global_reward -30
# action [0.9907129]
# position [ 0.99071288 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.9907129], effect False, done False, global_reward -31
# action [0.9483416]
# position [ 0.94834161 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.9483416], effect False, done False, global_reward -32
# action [0.7879579]
# position [ 0.78795791 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.7879579], effect False, done False, global_reward -33
# action [0.81497717]
# position [ 0.81497717 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.81497717], effect False, done False, global_reward -34
# action [0.96959496]
# position [ 0.96959496 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.96959496], effect False, done False, global_reward -35
# action [0.719066]
# position [ 0.71906602 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.719066], effect False, done False, global_reward -36
# action [0.9162648]
# position [ 0.91626477 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.9162648], effect False, done False, global_reward -37
# action [0.9206598]
# position [ 0.92065978 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.9206598], effect False, done False, global_reward -38
# action [0.92366076]
# position [ 0.92366076 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.92366076], effect False, done False, global_reward -39
# action [0.88874197]
# position [ 0.88874197 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.88874197], effect False, done False, global_reward -40
# action [0.9084618]
# position [ 0.90846181 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.9084618], effect False, done False, global_reward -41
# action [0.8835654]
# position [ 0.88356543 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.8835654], effect False, done False, global_reward -42
# action [0.8382623]
# position [ 0.83826232 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.8382623], effect False, done False, global_reward -43
# action [0.9821181]
# position [ 0.98211813 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.9821181], effect False, done False, global_reward -44
# action [0.9908849]
# position [ 0.9908849  -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.9908849], effect False, done False, global_reward -45
# action [0.98390317]
# position [ 0.98390317 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.98390317], effect False, done False, global_reward -46
# action [0.98204374]
# position [ 0.98204374 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.98204374], effect False, done False, global_reward -47
# action [0.96766067]
# position [ 0.96766067 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.96766067], effect False, done False, global_reward -48
# action [0.97697926]
# position [ 0.97697926 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.97697926], effect False, done False, global_reward -49
# action [0.7651099]
# position [ 0.7651099  -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.7651099], effect False, done False, global_reward -50
# action [0.7888019]
# position [ 0.78880191 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.7888019], effect False, done False, global_reward -51
# action [0.8169904]
# position [ 0.81699038 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.8169904], effect False, done False, global_reward -52
# action [0.9822879]
# position [ 0.98228788 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.9822879], effect False, done False, global_reward -53
# action [0.8021425]
# position [ 0.8021425  -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.8021425], effect False, done False, global_reward -54
# action [0.9837651]
# position [ 0.98376513 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.9837651], effect False, done False, global_reward -55
# action [0.9073436]
# position [ 0.90734363 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.9073436], effect False, done False, global_reward -56
# action [0.8533077]
# position [ 0.85330772 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.8533077], effect False, done False, global_reward -57
# action [0.9490298]
# position [ 0.9490298  -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.9490298], effect False, done False, global_reward -58
# action [0.9802499]
# position [ 0.98024988 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.9802499], effect False, done False, global_reward -59
# action [0.87534916]
# position [ 0.87534916 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.87534916], effect False, done False, global_reward -60
# action [0.77365637]
# position [ 0.77365637 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.77365637], effect False, done False, global_reward -61
# action [0.9500246]
# position [ 0.9500246  -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.9500246], effect False, done False, global_reward -62
# action [0.8876209]
# position [ 0.88762093 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.8876209], effect False, done False, global_reward -63
# action [0.9898963]
# position [ 0.9898963  -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.9898963], effect False, done False, global_reward -64
# action [0.9649997]
# position [ 0.96499968 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.9649997], effect False, done False, global_reward -65
# action [0.99591553]
# position [ 0.99591553 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.99591553], effect False, done False, global_reward -66
# action [0.86899686]
# position [ 0.86899686 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.86899686], effect False, done False, global_reward -67
# action [0.9872955]
# position [ 0.98729551 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.9872955], effect False, done False, global_reward -68
# action [0.9357035]
# position [ 0.93570352 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.9357035], effect False, done False, global_reward -69
# action [0.9785999]
# position [ 0.97859991 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.9785999], effect False, done False, global_reward -70
# action [0.9852834]
# position [ 0.98528337 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.9852834], effect False, done False, global_reward -71
# action [0.925558]
# position [ 0.92555797 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.925558], effect False, done False, global_reward -72
# action [0.9788846]
# position [ 0.97888458 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.9788846], effect False, done False, global_reward -73
# action [0.9395821]
# position [ 0.93958211 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.9395821], effect False, done False, global_reward -74
# action [0.90982556]
# position [ 0.90982556 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.90982556], effect False, done False, global_reward -75
# action [0.8753574]
# position [ 0.87535739 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.8753574], effect False, done False, global_reward -76
# action [0.9716952]
# position [ 0.97169518 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.9716952], effect False, done False, global_reward -77
# action [0.96982265]
# position [ 0.96982265 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.96982265], effect False, done False, global_reward -78
# action [0.95682645]
# position [ 0.95682645 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.95682645], effect False, done False, global_reward -79
# action [0.906214]
# position [ 0.906214   -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.906214], effect False, done False, global_reward -80
# action [0.96975875]
# position [ 0.96975875 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.96975875], effect False, done False, global_reward -81
# action [0.8740101]
# position [ 0.87401009 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.8740101], effect False, done False, global_reward -82
# action [0.8549626]
# position [ 0.85496259 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.8549626], effect False, done False, global_reward -83
# action [0.8280289]
# position [ 0.82802892 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.8280289], effect False, done False, global_reward -84
# action [0.94508195]
# position [ 0.94508195 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.94508195], effect False, done False, global_reward -85
# action [0.8180306]
# position [ 0.8180306  -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.8180306], effect False, done False, global_reward -86
# action [0.9575728]
# position [ 0.95757282 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.9575728], effect False, done False, global_reward -87
# action [0.9491]
# position [ 0.94910002 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.9491], effect False, done False, global_reward -88
# action [0.8572347]
# position [ 0.85723472 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.8572347], effect False, done False, global_reward -89
# action [0.9323926]
# position [ 0.9323926  -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.9323926], effect False, done False, global_reward -90
# action [0.9611926]
# position [ 0.96119261 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.9611926], effect False, done False, global_reward -91
# action [0.98317873]
# position [ 0.98317873 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.98317873], effect False, done False, global_reward -92
# action [0.95229125]
# position [ 0.95229125 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.95229125], effect False, done False, global_reward -93
# action [0.9626112]
# position [ 0.9626112  -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.9626112], effect False, done False, global_reward -94
# action [0.9468696]
# position [ 0.94686961 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.9468696], effect False, done False, global_reward -95
# action [0.96487117]
# position [ 0.96487117 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.96487117], effect False, done False, global_reward -96
# action [0.8811078]
# position [ 0.88110781 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.8811078], effect False, done False, global_reward -97
# action [0.9667702]
# position [ 0.96677017 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.9667702], effect False, done False, global_reward -98
# action [0.7944145]
# position [ 0.79441452 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.7944145], effect False, done False, global_reward -99
# action [0.9762163]
# position [ 0.97621632 -0.76       -0.67567568 -0.52941176  0.93877551 -0.98089959
#  -0.63076923 -0.63076923 -0.2         0.        ], action [0.9762163], effect False, done False, global_reward -100

# %% [markdown]
# # TD3 training

# %%
from stable_baselines3 import TD3
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise

model_name = "janus partial td3 - reward clown hat noborder"

janus_env = Janus()
check_env(janus_env)

n_actions = janus_env.action_space.shape[-1]
action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))
action_noise = OrnsteinUhlenbeckActionNoise(mean=np.zeros(n_actions), sigma=float(0.5) * np.ones(n_actions))

model_janus_td3 = TD3("MlpPolicy", janus_env, action_noise=action_noise, verbose=2,tensorboard_log="./tensorboard/")
model_janus_td3.learn(total_timesteps=1000, log_interval=4, tb_log_name=model_name)
model_janus_td3.save("./data/"+model_name)
# Out:
# features shape: (782, 228),
# targets shape: (782, 2)
#
# Length of train is 703, test is 79
# R squared: 0.6615
# Output steps:  [0.064, 0.057]
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to ./tensorboard/janus partial td3 - reward clown hat noborder_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8        |
# |    ep_rew_mean     | 93       |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 21       |
# |    time_elapsed    | 1        |
# |    total timesteps | 32       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10       |
# |    ep_rew_mean     | 91       |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 23       |
# |    time_elapsed    | 3        |
# |    total timesteps | 80       |
# ---------------------------------
# episode too long -> reset
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16.4     |
# |    ep_rew_mean     | 76.2     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 23       |
# |    time_elapsed    | 8        |
# |    total timesteps | 197      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12.6     |
# |    ep_rew_mean     | 82.2     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 18       |
# |    time_elapsed    | 10       |
# |    total timesteps | 201      |
# | train/             |          |
# |    actor_loss      | -8.28    |
# |    critic_loss     | 694      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 104      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10.2     |
# |    ep_rew_mean     | 85.7     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 18       |
# |    time_elapsed    | 11       |
# |    total timesteps | 205      |
# | train/             |          |
# |    actor_loss      | -13.8    |
# |    critic_loss     | 1.33e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 108      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.71     |
# |    ep_rew_mean     | 88.1     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 18       |
# |    time_elapsed    | 11       |
# |    total timesteps | 209      |
# | train/             |          |
# |    actor_loss      | -22.5    |
# |    critic_loss     | 1.36e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 112      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 7.61     |
# |    ep_rew_mean     | 89.8     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 18       |
# |    time_elapsed    | 11       |
# |    total timesteps | 213      |
# | train/             |          |
# |    actor_loss      | -16.1    |
# |    critic_loss     | 2.47e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 116      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.78     |
# |    ep_rew_mean     | 91.1     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 17       |
# |    time_elapsed    | 12       |
# |    total timesteps | 217      |
# | train/             |          |
# |    actor_loss      | -25.8    |
# |    critic_loss     | 1.82e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 120      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.14     |
# |    ep_rew_mean     | 92.1     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 17       |
# |    time_elapsed    | 12       |
# |    total timesteps | 221      |
# | train/             |          |
# |    actor_loss      | -29.8    |
# |    critic_loss     | 1.61e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 124      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.62     |
# |    ep_rew_mean     | 92.8     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 17       |
# |    time_elapsed    | 13       |
# |    total timesteps | 225      |
# | train/             |          |
# |    actor_loss      | -39.3    |
# |    critic_loss     | 2.25e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 128      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.2      |
# |    ep_rew_mean     | 93.5     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 17       |
# |    time_elapsed    | 13       |
# |    total timesteps | 229      |
# | train/             |          |
# |    actor_loss      | -48.7    |
# |    critic_loss     | 2.28e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 132      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4.85     |
# |    ep_rew_mean     | 94       |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 16       |
# |    time_elapsed    | 13       |
# |    total timesteps | 233      |
# | train/             |          |
# |    actor_loss      | -48.4    |
# |    critic_loss     | 1.09e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 136      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4.56     |
# |    ep_rew_mean     | 94.5     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 16       |
# |    time_elapsed    | 14       |
# |    total timesteps | 237      |
# | train/             |          |
# |    actor_loss      | -53.4    |
# |    critic_loss     | 1.23e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 140      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4.3      |
# |    ep_rew_mean     | 94.9     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 16       |
# |    time_elapsed    | 14       |
# |    total timesteps | 241      |
# | train/             |          |
# |    actor_loss      | -71.8    |
# |    critic_loss     | 775      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 144      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4.08     |
# |    ep_rew_mean     | 95.2     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 16       |
# |    time_elapsed    | 15       |
# |    total timesteps | 245      |
# | train/             |          |
# |    actor_loss      | -70.5    |
# |    critic_loss     | 865      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 148      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.89     |
# |    ep_rew_mean     | 95.5     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 16       |
# |    time_elapsed    | 15       |
# |    total timesteps | 249      |
# | train/             |          |
# |    actor_loss      | -83.8    |
# |    critic_loss     | 529      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 152      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.72     |
# |    ep_rew_mean     | 95.8     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 15       |
# |    time_elapsed    | 15       |
# |    total timesteps | 253      |
# | train/             |          |
# |    actor_loss      | -58.7    |
# |    critic_loss     | 371      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 156      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.57     |
# |    ep_rew_mean     | 96       |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 15       |
# |    time_elapsed    | 16       |
# |    total timesteps | 257      |
# | train/             |          |
# |    actor_loss      | -90.3    |
# |    critic_loss     | 626      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 160      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.43     |
# |    ep_rew_mean     | 96.2     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 15       |
# |    time_elapsed    | 16       |
# |    total timesteps | 261      |
# | train/             |          |
# |    actor_loss      | -70.3    |
# |    critic_loss     | 282      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 164      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.31     |
# |    ep_rew_mean     | 96.4     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 15       |
# |    time_elapsed    | 17       |
# |    total timesteps | 265      |
# | train/             |          |
# |    actor_loss      | -84      |
# |    critic_loss     | 807      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 168      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.2      |
# |    ep_rew_mean     | 96.6     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 15       |
# |    time_elapsed    | 17       |
# |    total timesteps | 269      |
# | train/             |          |
# |    actor_loss      | -76.5    |
# |    critic_loss     | 546      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 172      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.1      |
# |    ep_rew_mean     | 96.7     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 15       |
# |    time_elapsed    | 18       |
# |    total timesteps | 273      |
# | train/             |          |
# |    actor_loss      | -82.3    |
# |    critic_loss     | 354      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 176      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.01     |
# |    ep_rew_mean     | 96.9     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 14       |
# |    time_elapsed    | 18       |
# |    total timesteps | 277      |
# | train/             |          |
# |    actor_loss      | -77      |
# |    critic_loss     | 495      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 180      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.93     |
# |    ep_rew_mean     | 97       |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 14       |
# |    time_elapsed    | 18       |
# |    total timesteps | 281      |
# | train/             |          |
# |    actor_loss      | -84.4    |
# |    critic_loss     | 504      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 184      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.85     |
# |    ep_rew_mean     | 97.1     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 14       |
# |    time_elapsed    | 19       |
# |    total timesteps | 285      |
# | train/             |          |
# |    actor_loss      | -74.9    |
# |    critic_loss     | 521      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 188      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.57     |
# |    ep_rew_mean     | 97.4     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 14       |
# |    time_elapsed    | 19       |
# |    total timesteps | 289      |
# | train/             |          |
# |    actor_loss      | -86.4    |
# |    critic_loss     | 484      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 192      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.13     |
# |    ep_rew_mean     | 97.8     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 14       |
# |    time_elapsed    | 20       |
# |    total timesteps | 293      |
# | train/             |          |
# |    actor_loss      | -84.6    |
# |    critic_loss     | 277      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 196      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 14       |
# |    time_elapsed    | 20       |
# |    total timesteps | 297      |
# | train/             |          |
# |    actor_loss      | -79.5    |
# |    critic_loss     | 282      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 200      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 14       |
# |    time_elapsed    | 21       |
# |    total timesteps | 301      |
# | train/             |          |
# |    actor_loss      | -92.2    |
# |    critic_loss     | 386      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 204      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 14       |
# |    time_elapsed    | 21       |
# |    total timesteps | 305      |
# | train/             |          |
# |    actor_loss      | -82.9    |
# |    critic_loss     | 591      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 208      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 14       |
# |    time_elapsed    | 21       |
# |    total timesteps | 309      |
# | train/             |          |
# |    actor_loss      | -81.9    |
# |    critic_loss     | 240      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 212      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 14       |
# |    time_elapsed    | 22       |
# |    total timesteps | 313      |
# | train/             |          |
# |    actor_loss      | -83.6    |
# |    critic_loss     | 76.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 216      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 13       |
# |    time_elapsed    | 22       |
# |    total timesteps | 317      |
# | train/             |          |
# |    actor_loss      | -90.7    |
# |    critic_loss     | 378      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 220      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 13       |
# |    time_elapsed    | 23       |
# |    total timesteps | 321      |
# | train/             |          |
# |    actor_loss      | -84.1    |
# |    critic_loss     | 218      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 224      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 13       |
# |    time_elapsed    | 23       |
# |    total timesteps | 325      |
# | train/             |          |
# |    actor_loss      | -88.4    |
# |    critic_loss     | 429      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 228      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 13       |
# |    time_elapsed    | 23       |
# |    total timesteps | 329      |
# | train/             |          |
# |    actor_loss      | -86.2    |
# |    critic_loss     | 378      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 232      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 13       |
# |    time_elapsed    | 24       |
# |    total timesteps | 333      |
# | train/             |          |
# |    actor_loss      | -86.8    |
# |    critic_loss     | 472      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 236      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 13       |
# |    time_elapsed    | 24       |
# |    total timesteps | 337      |
# | train/             |          |
# |    actor_loss      | -88      |
# |    critic_loss     | 129      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 240      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 13       |
# |    time_elapsed    | 25       |
# |    total timesteps | 341      |
# | train/             |          |
# |    actor_loss      | -87.4    |
# |    critic_loss     | 397      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 244      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 13       |
# |    time_elapsed    | 25       |
# |    total timesteps | 345      |
# | train/             |          |
# |    actor_loss      | -85.1    |
# |    critic_loss     | 296      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 248      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 13       |
# |    time_elapsed    | 25       |
# |    total timesteps | 349      |
# | train/             |          |
# |    actor_loss      | -100     |
# |    critic_loss     | 231      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 252      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 13       |
# |    time_elapsed    | 26       |
# |    total timesteps | 353      |
# | train/             |          |
# |    actor_loss      | -78.8    |
# |    critic_loss     | 213      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 256      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 13       |
# |    time_elapsed    | 26       |
# |    total timesteps | 357      |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 292      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 260      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 13       |
# |    time_elapsed    | 26       |
# |    total timesteps | 361      |
# | train/             |          |
# |    actor_loss      | -78.9    |
# |    critic_loss     | 369      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 264      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 13       |
# |    time_elapsed    | 27       |
# |    total timesteps | 365      |
# | train/             |          |
# |    actor_loss      | -100     |
# |    critic_loss     | 345      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 268      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 13       |
# |    time_elapsed    | 27       |
# |    total timesteps | 369      |
# | train/             |          |
# |    actor_loss      | -83.5    |
# |    critic_loss     | 201      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 272      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 13       |
# |    time_elapsed    | 28       |
# |    total timesteps | 373      |
# | train/             |          |
# |    actor_loss      | -93.5    |
# |    critic_loss     | 231      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 276      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 13       |
# |    time_elapsed    | 28       |
# |    total timesteps | 377      |
# | train/             |          |
# |    actor_loss      | -91.1    |
# |    critic_loss     | 228      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 280      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 13       |
# |    time_elapsed    | 28       |
# |    total timesteps | 381      |
# | train/             |          |
# |    actor_loss      | -89.2    |
# |    critic_loss     | 242      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 284      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 13       |
# |    time_elapsed    | 29       |
# |    total timesteps | 385      |
# | train/             |          |
# |    actor_loss      | -88.6    |
# |    critic_loss     | 85.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 288      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 13       |
# |    time_elapsed    | 29       |
# |    total timesteps | 389      |
# | train/             |          |
# |    actor_loss      | -93.8    |
# |    critic_loss     | 184      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 292      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 13       |
# |    time_elapsed    | 30       |
# |    total timesteps | 393      |
# | train/             |          |
# |    actor_loss      | -92.1    |
# |    critic_loss     | 105      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 296      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 13       |
# |    time_elapsed    | 30       |
# |    total timesteps | 397      |
# | train/             |          |
# |    actor_loss      | -91.1    |
# |    critic_loss     | 191      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 300      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 12       |
# |    time_elapsed    | 30       |
# |    total timesteps | 401      |
# | train/             |          |
# |    actor_loss      | -87.2    |
# |    critic_loss     | 207      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 304      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 12       |
# |    time_elapsed    | 31       |
# |    total timesteps | 405      |
# | train/             |          |
# |    actor_loss      | -96.5    |
# |    critic_loss     | 317      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 308      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 12       |
# |    time_elapsed    | 31       |
# |    total timesteps | 409      |
# | train/             |          |
# |    actor_loss      | -87.2    |
# |    critic_loss     | 164      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 312      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 12       |
# |    time_elapsed    | 32       |
# |    total timesteps | 413      |
# | train/             |          |
# |    actor_loss      | -96.4    |
# |    critic_loss     | 319      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 316      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 12       |
# |    time_elapsed    | 32       |
# |    total timesteps | 417      |
# | train/             |          |
# |    actor_loss      | -91.6    |
# |    critic_loss     | 145      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 320      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 12       |
# |    time_elapsed    | 32       |
# |    total timesteps | 421      |
# | train/             |          |
# |    actor_loss      | -93.9    |
# |    critic_loss     | 116      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 324      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 12       |
# |    time_elapsed    | 33       |
# |    total timesteps | 425      |
# | train/             |          |
# |    actor_loss      | -92.2    |
# |    critic_loss     | 240      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 328      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 12       |
# |    time_elapsed    | 33       |
# |    total timesteps | 429      |
# | train/             |          |
# |    actor_loss      | -95.2    |
# |    critic_loss     | 131      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 332      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 12       |
# |    time_elapsed    | 34       |
# |    total timesteps | 433      |
# | train/             |          |
# |    actor_loss      | -90.5    |
# |    critic_loss     | 218      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 336      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 12       |
# |    time_elapsed    | 34       |
# |    total timesteps | 437      |
# | train/             |          |
# |    actor_loss      | -97.1    |
# |    critic_loss     | 190      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 340      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 12       |
# |    time_elapsed    | 34       |
# |    total timesteps | 441      |
# | train/             |          |
# |    actor_loss      | -92.6    |
# |    critic_loss     | 156      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 344      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 12       |
# |    time_elapsed    | 35       |
# |    total timesteps | 445      |
# | train/             |          |
# |    actor_loss      | -96.6    |
# |    critic_loss     | 138      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 348      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 12       |
# |    time_elapsed    | 35       |
# |    total timesteps | 449      |
# | train/             |          |
# |    actor_loss      | -92.5    |
# |    critic_loss     | 111      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 352      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 12       |
# |    time_elapsed    | 35       |
# |    total timesteps | 453      |
# | train/             |          |
# |    actor_loss      | -97.7    |
# |    critic_loss     | 114      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 356      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 12       |
# |    time_elapsed    | 36       |
# |    total timesteps | 457      |
# | train/             |          |
# |    actor_loss      | -92      |
# |    critic_loss     | 200      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 360      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 12       |
# |    time_elapsed    | 36       |
# |    total timesteps | 461      |
# | train/             |          |
# |    actor_loss      | -96.6    |
# |    critic_loss     | 343      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 364      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 12       |
# |    time_elapsed    | 37       |
# |    total timesteps | 465      |
# | train/             |          |
# |    actor_loss      | -93.8    |
# |    critic_loss     | 178      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 368      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 12       |
# |    time_elapsed    | 37       |
# |    total timesteps | 469      |
# | train/             |          |
# |    actor_loss      | -95.4    |
# |    critic_loss     | 83.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 372      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 12       |
# |    time_elapsed    | 37       |
# |    total timesteps | 473      |
# | train/             |          |
# |    actor_loss      | -96.6    |
# |    critic_loss     | 117      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 376      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 12       |
# |    time_elapsed    | 38       |
# |    total timesteps | 477      |
# | train/             |          |
# |    actor_loss      | -93.2    |
# |    critic_loss     | 81.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 380      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 12       |
# |    time_elapsed    | 38       |
# |    total timesteps | 481      |
# | train/             |          |
# |    actor_loss      | -96      |
# |    critic_loss     | 134      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 384      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 12       |
# |    time_elapsed    | 38       |
# |    total timesteps | 485      |
# | train/             |          |
# |    actor_loss      | -95.1    |
# |    critic_loss     | 156      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 388      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 12       |
# |    time_elapsed    | 39       |
# |    total timesteps | 489      |
# | train/             |          |
# |    actor_loss      | -96.5    |
# |    critic_loss     | 167      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 392      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 12       |
# |    time_elapsed    | 39       |
# |    total timesteps | 493      |
# | train/             |          |
# |    actor_loss      | -92.4    |
# |    critic_loss     | 153      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 396      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 12       |
# |    time_elapsed    | 40       |
# |    total timesteps | 497      |
# | train/             |          |
# |    actor_loss      | -97.9    |
# |    critic_loss     | 76.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 400      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 12       |
# |    time_elapsed    | 40       |
# |    total timesteps | 501      |
# | train/             |          |
# |    actor_loss      | -98.9    |
# |    critic_loss     | 88       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 404      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 12       |
# |    time_elapsed    | 40       |
# |    total timesteps | 505      |
# | train/             |          |
# |    actor_loss      | -97.1    |
# |    critic_loss     | 113      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 408      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 12       |
# |    time_elapsed    | 41       |
# |    total timesteps | 509      |
# | train/             |          |
# |    actor_loss      | -96.7    |
# |    critic_loss     | 69.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 412      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 12       |
# |    time_elapsed    | 41       |
# |    total timesteps | 513      |
# | train/             |          |
# |    actor_loss      | -94.8    |
# |    critic_loss     | 35.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 416      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 12       |
# |    time_elapsed    | 41       |
# |    total timesteps | 517      |
# | train/             |          |
# |    actor_loss      | -97.7    |
# |    critic_loss     | 25.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 420      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 12       |
# |    time_elapsed    | 42       |
# |    total timesteps | 521      |
# | train/             |          |
# |    actor_loss      | -99.2    |
# |    critic_loss     | 144      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 424      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 12       |
# |    time_elapsed    | 42       |
# |    total timesteps | 525      |
# | train/             |          |
# |    actor_loss      | -96.6    |
# |    critic_loss     | 46       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 428      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 344      |
# |    fps             | 12       |
# |    time_elapsed    | 43       |
# |    total timesteps | 529      |
# | train/             |          |
# |    actor_loss      | -98.5    |
# |    critic_loss     | 132      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 432      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 348      |
# |    fps             | 12       |
# |    time_elapsed    | 43       |
# |    total timesteps | 533      |
# | train/             |          |
# |    actor_loss      | -94.8    |
# |    critic_loss     | 167      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 436      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 352      |
# |    fps             | 12       |
# |    time_elapsed    | 43       |
# |    total timesteps | 537      |
# | train/             |          |
# |    actor_loss      | -97.6    |
# |    critic_loss     | 164      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 440      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 356      |
# |    fps             | 12       |
# |    time_elapsed    | 44       |
# |    total timesteps | 541      |
# | train/             |          |
# |    actor_loss      | -99.2    |
# |    critic_loss     | 302      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 444      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 12       |
# |    time_elapsed    | 44       |
# |    total timesteps | 545      |
# | train/             |          |
# |    actor_loss      | -91.1    |
# |    critic_loss     | 112      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 448      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 364      |
# |    fps             | 12       |
# |    time_elapsed    | 45       |
# |    total timesteps | 549      |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 49.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 452      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 368      |
# |    fps             | 12       |
# |    time_elapsed    | 45       |
# |    total timesteps | 553      |
# | train/             |          |
# |    actor_loss      | -91      |
# |    critic_loss     | 201      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 456      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 372      |
# |    fps             | 12       |
# |    time_elapsed    | 45       |
# |    total timesteps | 557      |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 81.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 460      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 376      |
# |    fps             | 12       |
# |    time_elapsed    | 46       |
# |    total timesteps | 561      |
# | train/             |          |
# |    actor_loss      | -94.5    |
# |    critic_loss     | 70.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 464      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 380      |
# |    fps             | 12       |
# ...
# |    actor_loss      | -99.2    |
# |    critic_loss     | 62       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 776      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 692      |
# |    fps             | 11       |
# |    time_elapsed    | 76       |
# |    total timesteps | 877      |
# | train/             |          |
# |    actor_loss      | -99.2    |
# |    critic_loss     | 24.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 780      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 696      |
# |    fps             | 11       |
# |    time_elapsed    | 77       |
# |    total timesteps | 881      |
# | train/             |          |
# |    actor_loss      | -100     |
# |    critic_loss     | 13       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 784      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 700      |
# |    fps             | 11       |
# |    time_elapsed    | 77       |
# |    total timesteps | 885      |
# | train/             |          |
# |    actor_loss      | -99.7    |
# |    critic_loss     | 14.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 788      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 704      |
# |    fps             | 11       |
# |    time_elapsed    | 77       |
# |    total timesteps | 889      |
# | train/             |          |
# |    actor_loss      | -99.3    |
# |    critic_loss     | 24.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 792      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 708      |
# |    fps             | 11       |
# |    time_elapsed    | 78       |
# |    total timesteps | 893      |
# | train/             |          |
# |    actor_loss      | -100     |
# |    critic_loss     | 36.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 796      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 712      |
# |    fps             | 11       |
# |    time_elapsed    | 78       |
# |    total timesteps | 897      |
# | train/             |          |
# |    actor_loss      | -99.6    |
# |    critic_loss     | 11.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 800      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 716      |
# |    fps             | 11       |
# |    time_elapsed    | 79       |
# |    total timesteps | 901      |
# | train/             |          |
# |    actor_loss      | -100     |
# |    critic_loss     | 76.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 804      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 720      |
# |    fps             | 11       |
# |    time_elapsed    | 79       |
# |    total timesteps | 905      |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 89.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 808      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 724      |
# |    fps             | 11       |
# |    time_elapsed    | 79       |
# |    total timesteps | 909      |
# | train/             |          |
# |    actor_loss      | -98.1    |
# |    critic_loss     | 21.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 812      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 728      |
# |    fps             | 11       |
# |    time_elapsed    | 80       |
# |    total timesteps | 913      |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 60.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 816      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 732      |
# |    fps             | 11       |
# |    time_elapsed    | 80       |
# |    total timesteps | 917      |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 21.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 820      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 736      |
# |    fps             | 11       |
# |    time_elapsed    | 81       |
# |    total timesteps | 921      |
# | train/             |          |
# |    actor_loss      | -99.2    |
# |    critic_loss     | 39.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 824      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 740      |
# |    fps             | 11       |
# |    time_elapsed    | 81       |
# |    total timesteps | 925      |
# | train/             |          |
# |    actor_loss      | -100     |
# |    critic_loss     | 21.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 828      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 744      |
# |    fps             | 11       |
# |    time_elapsed    | 81       |
# |    total timesteps | 929      |
# | train/             |          |
# |    actor_loss      | -98.9    |
# |    critic_loss     | 32.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 832      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 748      |
# |    fps             | 11       |
# |    time_elapsed    | 82       |
# |    total timesteps | 933      |
# | train/             |          |
# |    actor_loss      | -99.7    |
# |    critic_loss     | 14.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 836      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 752      |
# |    fps             | 11       |
# |    time_elapsed    | 82       |
# |    total timesteps | 937      |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 15.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 840      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 756      |
# |    fps             | 11       |
# |    time_elapsed    | 83       |
# |    total timesteps | 941      |
# | train/             |          |
# |    actor_loss      | -99.5    |
# |    critic_loss     | 14.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 844      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 760      |
# |    fps             | 11       |
# |    time_elapsed    | 83       |
# |    total timesteps | 945      |
# | train/             |          |
# |    actor_loss      | -98.6    |
# |    critic_loss     | 27.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 848      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 764      |
# |    fps             | 11       |
# |    time_elapsed    | 83       |
# |    total timesteps | 949      |
# | train/             |          |
# |    actor_loss      | -99.5    |
# |    critic_loss     | 49.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 852      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 768      |
# |    fps             | 11       |
# |    time_elapsed    | 84       |
# |    total timesteps | 953      |
# | train/             |          |
# |    actor_loss      | -100     |
# |    critic_loss     | 29.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 856      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 772      |
# |    fps             | 11       |
# |    time_elapsed    | 84       |
# |    total timesteps | 957      |
# | train/             |          |
# |    actor_loss      | -99.1    |
# |    critic_loss     | 49.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 860      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 776      |
# |    fps             | 11       |
# |    time_elapsed    | 84       |
# |    total timesteps | 961      |
# | train/             |          |
# |    actor_loss      | -100     |
# |    critic_loss     | 41.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 864      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 780      |
# |    fps             | 11       |
# |    time_elapsed    | 85       |
# |    total timesteps | 965      |
# | train/             |          |
# |    actor_loss      | -99.8    |
# |    critic_loss     | 14.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 868      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 784      |
# |    fps             | 11       |
# |    time_elapsed    | 85       |
# |    total timesteps | 969      |
# | train/             |          |
# |    actor_loss      | -99.1    |
# |    critic_loss     | 103      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 872      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 788      |
# |    fps             | 11       |
# |    time_elapsed    | 86       |
# |    total timesteps | 973      |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 58.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 876      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 792      |
# |    fps             | 11       |
# |    time_elapsed    | 86       |
# |    total timesteps | 977      |
# | train/             |          |
# |    actor_loss      | -98.7    |
# |    critic_loss     | 81.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 880      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 796      |
# |    fps             | 11       |
# |    time_elapsed    | 86       |
# |    total timesteps | 981      |
# | train/             |          |
# |    actor_loss      | -99.5    |
# |    critic_loss     | 15.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 884      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 800      |
# |    fps             | 11       |
# |    time_elapsed    | 87       |
# |    total timesteps | 985      |
# | train/             |          |
# |    actor_loss      | -100     |
# |    critic_loss     | 31.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 888      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 804      |
# |    fps             | 11       |
# |    time_elapsed    | 87       |
# |    total timesteps | 989      |
# | train/             |          |
# |    actor_loss      | -99.7    |
# |    critic_loss     | 26.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 892      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 808      |
# |    fps             | 11       |
# |    time_elapsed    | 88       |
# |    total timesteps | 993      |
# | train/             |          |
# |    actor_loss      | -99.8    |
# |    critic_loss     | 16.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 896      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 812      |
# |    fps             | 11       |
# |    time_elapsed    | 88       |
# |    total timesteps | 997      |
# | train/             |          |
# |    actor_loss      | -99.9    |
# |    critic_loss     | 34.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 900      |
# ---------------------------------

# %%
print(f'model used: {model_name}')

model_janus_td3 = TD3("MlpPolicy", janus_env, action_noise=action_noise, verbose=2,tensorboard_log="./tensorboard/")
model_janus_td3.load("./data/"+model_name)

janus_env.reset()
for i in range(100):
    action, _ = model_janus_td3.predict(janus_env.current_position)
    print(f'action {action}')
    obs, rewards, done, info = janus_env.step(action)
    janus_env.render()
    if done: 
        print(f'done within {i+1} iterations')
        break
janus_env.close()
# Out:
# model used: janus partial td3 - reward clown hat noborder
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# action [0.06333637 0.03861642 0.07715678 0.0893786 ]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.06333637 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.06333637 0.03861642 0.07715678 0.0893786 ], effect False, done False, global_reward -1.010
# action [0.05385339 0.04851985 0.08727157 0.09814668]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05385339 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05385339 0.04851985 0.08727157 0.09814668], effect False, done False, global_reward -2.020
# action [0.05373514 0.0484066  0.08724344 0.09837532]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373514 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373514 0.0484066  0.08724344 0.09837532], effect False, done False, global_reward -3.031
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -4.041
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -5.051
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -6.061
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -7.071
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -8.081
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -9.092
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -10.102
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -11.112
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -12.122
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -13.132
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -14.142
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -15.153
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -16.163
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -17.173
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -18.183
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -19.193
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -20.203
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -21.214
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -22.224
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -23.234
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -24.244
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -25.254
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -26.265
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -27.275
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -28.285
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -29.295
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -30.305
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -31.315
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -32.326
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -33.336
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -34.346
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -35.356
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -36.366
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -37.376
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -38.387
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -39.397
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -40.407
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -41.417
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -42.427
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -43.437
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -44.448
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -45.458
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -46.468
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -47.478
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -48.488
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -49.499
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -50.509
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -51.519
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -52.529
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -53.539
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -54.549
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -55.560
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -56.570
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -57.580
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -58.590
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -59.600
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -60.610
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -61.621
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -62.631
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -63.641
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -64.651
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -65.661
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -66.671
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -67.682
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -68.692
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -69.702
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -70.712
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -71.722
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -72.733
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -73.743
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -74.753
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -75.763
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -76.773
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -77.783
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -78.794
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -79.804
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -80.814
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -81.824
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -82.834
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -83.844
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -84.855
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -85.865
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -86.875
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -87.885
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -88.895
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -89.905
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -90.916
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -91.926
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -92.936
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -93.946
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -94.956
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -95.967
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -96.977
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -97.987
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -98.997
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -100.007
# action [0.05373454 0.0484035  0.08724427 0.09837389]
# position [ 0.12       -0.8        -0.7297297  -0.29411766  0.05373454 -0.9713494
#  -0.63076925 -0.63076925  0.2         0.1       ], action [0.05373454 0.0484035  0.08724427 0.09837389], effect False, done False, global_reward -101.017

# %%
janus_env = Janus()
check_env(janus_env)

# model_name = "janus partial td3 - reward clown hat"
print(f'model used: {model_name}')
model_janus_td3 = TD3("MlpPolicy", janus_env, action_noise=action_noise, verbose=2,tensorboard_log="./tensorboard/")
model_janus_td3.load("./data/"+model_name)

janus_env.reset()
new_y = janus_env.ml_model.predict(janus_env.convert_to_real_obs(janus_env.current_position,
                                     janus_env.full_x).values.reshape(1,-1)).reshape(-1)
print(f'init results:  {new_y} reward {janus_env.continuous_reward_clown_hat(new_y):0.03f} action {janus_env.last_action}')

for i in range(100):
    action, _ = model_janus_td3.predict(janus_env.current_position)
#     print(f'action {action}')
    obs, rewards, done, info = janus_env.step(action)
#     janus_env.render()
    if done: 
        print(f'done within {i+1} iterations')
        break
new_y = janus_env.ml_model.predict(janus_env.convert_to_real_obs(janus_env.current_position,
                                     janus_env.full_x).values.reshape(1,-1)).reshape(-1)
print(f'new results after {i+1} iterations:  {new_y} associated reward {janus_env.continuous_reward_clown_hat(new_y):0.03f}  action {janus_env.last_action}')
janus_env.vav_df
# Out:
# features shape: (782, 228),
# targets shape: (782, 2)
#
# Length of train is 703, test is 79
# R squared: 0.6615
# Output steps:  [0.064, 0.057]
# model used: janus partial td3 - reward clown hat noborder
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# init results:  [ 1.20198142 -0.3602791 ] reward -1.050 action [ 0.93877554  0.28554276 -0.3531915   0.57004833]
# new results after 100 iterations:  [ 1.07615165 -0.33756677] associated reward -0.996  action [ 0.01459515  0.06663322 -0.13415569  0.08507168]
#    target_0  target_5
# 0  0.984997 -0.170155

# %% [markdown]
# # plot target

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image

# Create figure and axes
fig, ax = plt.subplots()
janus_env = Janus()
# print(janus_env.vav_df)
# print(janus_env.ti)
# print(janus_env.ts)

inf_x = janus_env.ti.iloc[0][0]
sup_x = janus_env.ts.iloc[0][0]
inf_y = janus_env.ti.iloc[0][1]
sup_y = janus_env.ts.iloc[0][1]
inf_limx = min(inf_x, janus_env.y_df.min()[0])
sup_limx = max(sup_x, janus_env.y_df.max()[0])
inf_limy = min(inf_y, janus_env.y_df.min()[1])
sup_limy = max(sup_y, janus_env.y_df.max()[1])

# Create a Rectangle patch
rect = patches.Rectangle((inf_x, inf_y), (sup_x-inf_x), (sup_y-inf_y), linewidth=1, color='red', facecolor='none', label='CDC')
ax.add_patch(rect)

#create VAV point
plt.scatter(janus_env.vav_df.iloc[0].values[0], janus_env.vav_df.iloc[0].values[1], color='black', label='vav', zorder =2)

# Add the patch to the Axes
plt.xlim([inf_limx-1, sup_limx+1])
plt.ylim([inf_limy-1, sup_limy+1])
plt.legend()
plt.show()
# Out:
# features shape: (782, 228),
# targets shape: (782, 2)
#
# Length of train is 703, test is 79
# R squared: 0.6615
# Output steps:  [0.064, 0.057]
# C:\Users\F279814\AppData\Local\Continuum\anaconda3\envs\stablebaselines3\lib\site-packages\ipykernel_launcher.py:22: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.

# %%
import matplotlib.pyplot as plt
import numpy as np
from itertools import product

# Fixing random state for reproducibility
np.random.seed(19680801)


def randrange(n, vmin, vmax):
    """
    Helper function to make an array of random numbers having shape (n, )
    with each number distributed Uniform(vmin, vmax).
    """
    return (vmax - vmin)*np.random.rand(n) + vmin

fig = plt.figure()
ax = fig.add_subplot(projection='3d')

n = 100

# For each set of style and range settings, plot n random points in the box
# defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].

X = np.arange(inf_limx, sup_limx, 0.2)
Y = np.arange(inf_limy, sup_limy, 0.2)
for x in X:
    for y in Y:
        z = janus_env.continuous_reward_clown_hat([x, y])
        ax.scatter(x, y, z)
    

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()
